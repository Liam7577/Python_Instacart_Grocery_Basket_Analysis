# %%
## Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = '/Users/liamanderson/Desktop/Instacart Basket Analysis'

# %%
df_cust = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'cleaned_df_cust.pkl'))

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
## Merge the data sets together

cust_ords_prods = ords_prods_merge.merge(df_cust, on = 'user_id', indicator = True)

# %%
cust_ords_prods.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  ...  \
# 0   3139998     138            28                   6                 11  ...
# 1   1977647     138            30                   6                 17  ...
# 2    389851     709             2                   0                 21  ...
# 3    652770     764             1                   3                 13  ...
# 4   1813452     764             3                   4                 17  ...
#
# ...

# %%
## check value counts in _merge column

cust_ords_prods['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
## Export the data

cust_ords_prods.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_customers_merged.pkl'))
